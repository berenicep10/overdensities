# %% [markdown]
# In this notebook we analyse the CMDs and stellar distribution in the r band of the stars in pointing A763. This pointing is expected to probe the Gemini RRLyrae stream based on its position. Thus we are looking for an overdensity at the right distance ($R_{GC}\approx70$ kpc, which means $R_{helio}\approx70$ kpc).

# %% [markdown]
# ## Load libraries:

# %%
# %matplotlib inline
import numpy as np
#import asciidata as asd

import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
fontP = FontProperties()
fontP.set_size('small')

# %% [markdown]
# ## Load the data file and organize its columns into vectors:

# %%
#cat='/data1/piladiez/INT-ui/catalogues/stars_merged_4bands_A763.cat'
cat='/disks/shear7/piladiez/INT-ui/catalogues/stars_merged_4bands_A763.cat'
u,g,r,i=np.loadtxt(cat,usecols=[115,116,117,118],unpack=True)

ug=u-g
gr=g-r
ri=r-i
gi=g-i

# %%
#cat='/data1/piladiez/INT-ui/catalogues/stars_merged_4bands_A763.cat'
catF='/disks/shear7/piladiez/INT-ui/catalogues/nearMSTOstars_A763.cat'
uF,gF,rF,iF=np.loadtxt(catF,usecols=[115,116,117,118],unpack=True)

ugF=uF-gF
grF=gF-rF
riF=rF-iF
giF=gF-iF

# %% [markdown]
# ## Colour-Magnitude Diagrams:

# %%
import matplotlib
fontP.set_size('xx-small')

from matplotlib.colors import LogNorm

# %% [markdown]
# * Scatter plot (gray are all the point-like sources, red are the nearMSTO stars):

# %%
plt.figure(num=1)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')


plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

plt.ylim((25,15))

plt.plot(gr,r,'.k',ms=1)
plt.plot(grF,rF,'.r',ms=1)

# %% [markdown]
# * 2D-histogram colormesh:

# %%
# Estimate the 2D histogram
nbins = 100
H1, x1edges, y1edges = np.histogram2d(gr,r,bins=nbins)

# H needs to be rotated and flipped
H1 = np.rot90(H1)
H1 = np.flipud(H1)
 
# Mask zeros
H1masked = np.ma.masked_where(H1==0,H1) # Mask pixels with a value o

# %%
plt.figure(num=2)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

plt.ylim((25,15))

cmap = matplotlib.cm.spectral
plt.pcolormesh(x1edges,y1edges,H1masked,cmap=cmap)

cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')


#cmap = matplotlib.cm.spectral
#im=plt.imshow(ARRAY_chi2red_nq,extent=[min(RANGE_n),max(RANGE_n)+n_step,min(RANGE_q),max(RANGE_q)+q_step], 
#              aspect='auto',cmap=cmap)#, interpolation='nearest')#, norm=LogNorm()
#              #,aspect='auto')

#CS1 = plt.contour(ARRAY_chi2red_nq, levels=frange(np.min(ARRAY_chi2red_nq)+0.1, np.min(ARRAY_chi2red_nq)+0.7, 0.1), 
#                 colors='black', #origin='lower',linewidths=2,
#                 extent=[min(RANGE_n),max(RANGE_n)+n_step,max(RANGE_q)+q_step,min(RANGE_q)])
#plt.clabel(CS1, inline=1,fmt='%1.2f', fontsize=12)

#plt.show()

# %% [markdown]
# * 2D-histogram imshow (smoothed):

# %%
plt.figure(num=3)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

plt.xlim((-0.5,2.0))
plt.ylim((25,15.6))

cmap = matplotlib.cm.spectral
im = plt.imshow(H1masked, aspect='auto', origin='low',#interpolation='nearest',#norm=LogNorm(),
                extent=[x1edges[0], x1edges[-1], y1edges[0], y1edges[-1]],cmap=cmap)
cbar = plt.colorbar()

# %% [markdown]
# * 2D-histogram, directly plotted and unmasked (unlike option 2):

# %%
plt.figure(num=4)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

#plt.xlim(-0.5,2.0)


plt.hist2d(gr, r, bins=nbins)
plt.ylim((25,15.6))
cbar = plt.colorbar()

# %% [markdown]
# * Hexagonal binning:

# %%
plt.figure(num=5)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

#plt.xlim(-0.5,2.0)
plt.ylim((25,15.6))

plt.hexbin(gr, r, gridsize=nbins/2)#,bins='log')
cbar = plt.colorbar()

#cmap = matplotlib.cm.spectral
#im=plt.imshow(H1masked,extent=[min(x1edges),max(x1edges)+0.02,max(y1edges)-0.1,min(y1edges)], 
#              aspect='auto',cmap=cmap)#, interpolation='nearest')#, norm=LogNorm()
#              #,aspect='auto')

#CS1 = plt.contour(ARRAY_chi2red_nq, levels=frange(np.min(ARRAY_chi2red_nq)+0.1, np.min(ARRAY_chi2red_nq)+0.7, 0.1), 
#                 colors='black', #origin='lower',linewidths=2,
#                 extent=[min(RANGE_n),max(RANGE_n)+n_step,max(RANGE_q)+q_step,min(RANGE_q)])
#plt.clabel(CS1, inline=1,fmt='%1.2f', fontsize=12)

#plt.show()

# %% [markdown]
# * Gaussian kernel:

# %%
from scipy.stats import kde

# %%
plt.figure(num=6)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

plt.xlim(-0.4,1.6)
plt.ylim((25,15.6))

# Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
gr_kde=np.reshape(gr,(len(gr),1))
r_kde=np.reshape(r,(len(r),1))
data=np.hstack((gr_kde,r_kde))


k = kde.gaussian_kde(data.T,bw_method=0.1)  # 'scott' (default), 'silverman'
xi, yi = np.mgrid[gr_kde.min():gr_kde.max():nbins*1j, r_kde.min():r_kde.max():nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

#plt.set_title('Gaussian KDE')
plt.pcolormesh(xi, yi, zi.reshape(xi.shape))
plt.colorbar()

plt.show()

# %%
plt.figure(num=7)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('g-r', fontsize=14)
plt.ylabel('r (mag)', fontsize=14)

plt.xlim(-0.4,1.6)
plt.ylim((25,15.6))

Zi=zi.reshape(xi.shape)
Zi=Zi.T

im = plt.imshow(Zi, aspect='auto', origin='low',#norm=LogNorm(),#interpolation='nearest',
                extent=[x1edges[0], x1edges[-1], y1edges[0], y1edges[-1]],cmap=cmap)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xe9a2830>

# %% [markdown]
# ## Apparent magnitude histograms:

# %%
from lib_frange import frange

# %%
use_halo=np.where((0.2<gr) & (gr<0.3))
r_hist=r[use_halo]
g_hist=g[use_halo]
i_hist=i[use_halo]

#use_halo=np.where((g_hist<17) & (r_hist<17) & (g_hist<17))
#r_hist=r_hist[use_halo]
#g_hist=g_hist[use_halo]
#i_hist=i_hist[use_halo]

# %%
plt.figure(num=8)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('r (mag)', fontsize=14)
plt.ylabel('counts', fontsize=14)

Nbins_r=20
#plt.hist(r_hist,bins=Nbins_r,color='gray',normed=True)
plt.hist(r_hist,bins=frange(16.5,24.6,0.5),color='gray',label='stars in $0.2<g-r<0.3$')
plt.hist(rF,bins=frange(17.0,23.1,0.5),color='red',alpha=0.5,label='nearMSTO stars')
leg = plt.legend(fancybox=True, loc='upper right', ncol=1, fontsize=10, numpoints=1)  
leg.get_frame().set_alpha(0.5)
plt.show()

# %% [markdown]
# ## Heliocentric distance histograms:

# %% [markdown]
# * Apparent magnitude histogram for the three fields contributing to group G:

# %%
HDistF=np.loadtxt(catF,usecols=[122],unpack=True)


catA1246='/disks/shear7/piladiez/INT-ui/catalogues/nearMSTOstars_A1246.cat'
catZWCL1023='/disks/shear7/piladiez/INT-ui/catalogues/nearMSTOstars_ZWCL1023.cat'
uA,gA,rA,iA,HDistA=np.loadtxt(catA1246,usecols=[115,116,117,118,122],unpack=True)
uZ,gZ,rZ,iZ,HDistZ=np.loadtxt(catZWCL1023,usecols=[115,116,117,118,122],unpack=True)

# %%
plt.figure(num=9)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('r (mag)', fontsize=14)
plt.ylabel('counts', fontsize=14)

Nbins_r=20
#plt.hist(rA,bins=Nbins_r,color='blue',label='nearMSTO, A1246')
#plt.hist(rZ,bins=Nbins_r,color='green',alpha=0.85,label='nearMSTO, ZWCL1023')
#plt.hist(rF,bins=Nbins_r,color='red',alpha=0.7,label='nearMSTO, A763')
plt.hist(rA,bins=frange(17.0,23.1,0.5),color='blue',label='nearMSTO, A1246')
plt.hist(rZ,bins=frange(17.0,23.1,0.5),color='green',alpha=0.85,label='nearMSTO, ZWCL1023')
plt.hist(rF,bins=frange(17.0,23.1,0.5),color='red',alpha=0.7,label='nearMSTO, A763')
leg = plt.legend(fancybox=True, loc='upper left', ncol=1, fontsize=10, numpoints=1)  
leg.get_frame().set_alpha(0.5)
plt.show()

# %% [markdown]
# * Heliocentric distance histogram for the three fields contributing to group G:

# %%
plt.figure(num=10)#, figsize=(10,10))
plt.tick_params(labelsize=16) 
#plt.title('$\chi^2_{red}$ map for $n$ and $q$')

plt.xlabel('$Dist_{helio}$ (kpc)', fontsize=14)
plt.ylabel('counts', fontsize=14)

Nbins_r=20
#plt.hist(HDistA,bins=Nbins_r,color='blue',label='nearMSTO, A1246')
#plt.hist(HDistZ,bins=Nbins_r,color='green',alpha=0.85,label='nearMSTO, ZWCL1023')
#plt.hist(HDistF,bins=Nbins_r,color='red',alpha=0.7,label='nearMSTO, A763')
plt.hist(HDistA,bins=range(0,100,5),color='blue',label='nearMSTO, A1246')
plt.hist(HDistZ,bins=range(0,100,5),color='green',alpha=0.85,label='nearMSTO, ZWCL1023')
plt.hist(HDistF,bins=range(0,100,5),color='red',alpha=0.7,label='nearMSTO, A763')
leg = plt.legend(fancybox=True, loc='upper right', ncol=1, fontsize=10, numpoints=1)  
leg.get_frame().set_alpha(0.5)
plt.show()

# %%
AbsF=np.loadtxt(catF,usecols=[119],unpack=True)
AbsA=np.loadtxt(catA1246,usecols=[119],unpack=True)
AbsZ=np.loadtxt(catZWCL1023,usecols=[119],unpack=True)

# %%
plt.figure(num=11)#, figsize=(10,10))
plt.tick_params(labelsize=16)

plt.xlabel('HDist')
plt.ylabel('Abs mag (r)')

plt.plot(HDistA,AbsA,'.k',ms=2)
plt.plot(HDistF,AbsF,'.b',ms=2)
plt.plot(HDistZ,AbsZ,'.r',ms=2)
